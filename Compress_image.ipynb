# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwan08-bit/rizwan08/blob/main/Compress_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
img_path='/content/WhatsApp Image 2025-04-08 at 20.27.32_7f8f1cbc.jpg'

# %%
img=Image.open(img_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x433>

# %%
width, height = img.size
print("Width:", width)
print("Height:", height)
# Out:
# Width: 700
# Height: 433

# %%
new_width = int(width * 0.5)
new_height = int(height * 0.5)
resized_img = img.resize((new_width, new_height))

# %%
compressed_path = '/content/compressed_image.jpg'
resized_img.save(compressed_path, optimize=True, quality=85)

# %%
from IPython.display import Image as IPImage
display(IPImage(compressed_path))

# %%
width, height = resized_img.size
print("New Width:", width)
print("New Height:", height)
# Out:
# New Width: 350
# New Height: 216
