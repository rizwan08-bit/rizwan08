# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "//content/drive/MyDrive/house_price_regression_dataset.csv"
df = pd.read_csv(file_path)
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
df0=df[:333]
df1=df[333:666]
df2=df[666:]

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['Square_Footage']]
y = df['House_Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.model_selection import train_test_split

# %%
len(X_train)
# Out:
# 800

# %%
len(X_test)
# Out:
# 200

# %%
model = LinearRegression()
model.fit(X_train, y_train)
print(f"Slope: {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
# Out:
# Slope: 200.21142071369206
# Intercept: 57087.17914824409

# %%
plt.scatter(X, y, color='blue', label='Actual Data')  # Scatter plot of actual data
plt.plot(X, model.predict(X), color='red', label='Regression Line')  # Regression line
plt.xlabel('Square_Footage')
plt.ylabel('House_Price')
plt.title('Linear Regression: Square_Footage vs. House_Price')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9821643628933335
